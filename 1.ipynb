# %% [markdown]
# The mathematical formula for a linear Support Vector Machine (SVM) can be expressed as follows:
#
# Given a set of training data points
# (
# �
# �
# ,
# �
# �
# )
# (x
# i
# ​
#  ,y
# i
# ​
#  ), where
# �
# �
# x
# i
# ​
#   is the input feature vector and
# �
# �
# y
# i
# ​
#   is the corresponding class label (-1 or 1 for binary classification), the goal of a linear SVM is to find the hyperplane
# �
# ⋅
# �
# +
# �
# =
# 0
# w⋅x+b=0 that best separates the data into two classes.
#
# The decision function for a linear SVM is given by:
#
# �
# (
# �
# )
# =
# �
# ⋅
# �
# +
# �
# f(x)=w⋅x+b
#
# Here:
#
# �
# (
# �
# )
# f(x) represents the decision function.
# �
# w is the weight vector, which is perpendicular to the hyperplane.
# �
# x is the input feature vector.
# �
# b is the bias term.
# The classification rule is based on the sign of
# �
# (
# �
# )
# f(x):
#
# If
# �
# (
# �
# )
# ≥
# 0
# f(x)≥0, then the input
# �
# x is classified as class 1.
# If
# �
# (
# �
# )
# <
# 0
# f(x)<0, then the input
# �
# x is classified as class -1.
# The parameters
# �
# w and
# �
# b are learned during the training process to maximize the margin (distance) between the two classes. The optimization problem involves minimizing
# 1
# 2
# ∣
# ∣
# �
# ∣
# ∣
# 2
# 2
# 1
# ​
#  ∣∣w∣∣
# 2
#   subject to the constraint
# �
# �
# (
# �
# ⋅
# �
# �
# +
# �
# )
# ≥
# 1
# y
# i
# ​
#  (w⋅x
# i
# ​
#  +b)≥1 for all training data points.
