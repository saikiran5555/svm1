# %% [markdown]
# The objective function of a linear Support Vector Machine (SVM) is to find a hyperplane that best separates the data points of different classes in a feature space. The SVM aims to maximize the margin between the classes while minimizing the classification error.
#
# Mathematically, the objective function of a linear SVM can be expressed as:
#
# min
# ⁡
# �
# ,
# �
# 1
# 2
# ∣
# ∣
# �
# ∣
# ∣
# 2
# min
# w,b
# ​
#
# 2
# 1
# ​
#  ∣∣w∣∣
# 2
#
#
# subject to the constraints:
#
# �
# �
# (
# �
# ⋅
# �
# �
# +
# �
# )
# ≥
# 1
#  for all
# �
# y
# i
# ​
#  (w⋅x
# i
# ​
#  +b)≥1 for all i
#
# Here:
#
# �
# w is the weight vector that defines the orientation of the hyperplane,
# �
# b is the bias term that shifts the hyperplane,
# �
# �
# x
# i
# ​
#   represents the feature vector of the
# �
# i-th data point,
# �
# �
# y
# i
# ​
#   is the class label of the
# �
# i-th data point (either -1 or 1),
# ∣
# ∣
# �
# ∣
# ∣
# ∣∣w∣∣ is the Euclidean norm of the weight vector.
# The constraints ensure that data points are correctly classified on either side of the hyperplane with a margin of at least 1. The objective function aims to find the hyperplane with the maximum margin, making the SVM more robust to noise and improving generalization to unseen data. The minimization of
# ∣
# ∣
# �
# ∣
# ∣
# 2
# ∣∣w∣∣
# 2
#   is a regularization term that penalizes the complexity of the model, promoting a simpler and more generalizable solution.
